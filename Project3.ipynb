# %% [markdown]
# # SmartLab project 3
#
# The following paper compares a Fully Connected Network (FC) and a Convolutional Neural Network (CNN) in weather forecasting

# %% [markdown]
# ### Import packages, magic commands

# %%
# %matplotlib inline
# %autosave 60

import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
np.random.seed( 12)

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Conv1D, MaxPooling1D, BatchNormalization
from keras.callbacks import Callback
from keras.optimizers import Adam
from sklearn import preprocessing
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# ### Data import
#
# Below is the data import script but changed to comment because the [extracted csv file](https://drive.google.com/file/d/1i74iqIyODOz5iSrKTf7k3R1DqjMYausN/view?usp=sharing) is attached.
# The source is [World Weather Online's Past local API](https://www.worldweatheronline.com/developer/api/historical-weather-api.aspx).
#
# Contains 4 time-stamp variables which have been deleted because of standardization problem.
# After dropping has 20 predictors in a 4138 day period.

# %%
# from wwo_hist import retrieve_hist_data

# frequency = 24
# start_date = '01-JUL-2008'
# end_date = '16-OCT-2019'
# api_key = ''
# location_list = ['budapest']

# hist_weather_data = retrieve_hist_data( api_key,
#                                location_list,
#                                start_date,
#                                end_date,
#                                frequency,
#                                location_label = False,
#                                export_csv = True,
#                                store_df = True)

# %%
data = pd.read_csv( 'budapest.csv', header=0, index_col=0, parse_dates=True)

# %%
data.drop([ 'moonrise', 'moonset', 'sunrise', 'sunset'], axis=1, inplace=True)

# %% [markdown]
# ### Data preprocess for forecasting
#
# The forecast period can be specified in days with forecast_period variable.
# It shifts the target column with the given number.

# %%
forecast_period = 1

# %%
target = data[[ 'mintempC', 'maxtempC']].apply( np.mean, axis=1).shift( -forecast_period)

# %%
data.head()
# Out:
#             maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  uvIndex.1  \
# date_time
# 2008-07-01        30        16           0.0     14.5        6          6
# 2008-07-02        31        15           0.0     14.5        6          6
# 2008-07-03        31        19           0.0     14.5        6          6
# 2008-07-04        26        18           0.0     13.6        6          6
# 2008-07-05        25        16           0.0     14.5        6          6
#
#             moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  WindChillC  \
# date_time
# 2008-07-01                  4         15          24          24          24
# 2008-07-02                  0         13          25          25          24
# 2008-07-03                  0         10          26          26          25
# 2008-07-04                  3         13          22          22          22
# 2008-07-05                 10          9          21          21          21
#
#             WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  \
# date_time
# 2008-07-01             8           8        63       0.0      1018     30
# 2008-07-02            10          27        54       0.0      1015     31
# 2008-07-03            15           9        40       0.0      1012     31
# 2008-07-04            26          30        61       0.7      1009     26
# 2008-07-05            25           6        48       0.0      1012     25
#
#             visibility  winddirDegree  windspeedKmph
# date_time
# 2008-07-01           8            222              5
# 2008-07-02          10            143              6
# 2008-07-03          10            138             10
# 2008-07-04           9            282             19
# 2008-07-05          10            300             18

# %%
target.head()
# Out:
# date_time
# 2008-07-01    23.0
# 2008-07-02    25.0
# 2008-07-03    22.0
# 2008-07-04    20.5
# 2008-07-05    20.0
# dtype: float64

# %%
plt.figure( figsize= ( 15, 5))
plt.plot( target)
# Out:
# c:\python\python37\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Data splitting and scaling
#
# First snippet splits the dataset to 3 parts: train, validation and test.
# I specify the validation data here not in .fit() with validation_split because this way I can standardize it separately.
#
# I'm not sure about standardization, make a scaler on the whole training set or make a scaler on every variable in the training set therefore I left the first approach in a commented cell but the second approch makes more sense to me.

# %%
val_split = .2
test_split = .1
num_data = len( data)

x_train = data[ 0:int( num_data*( 1 - val_split - test_split))]
x_val = data[ int( num_data*( 1 - val_split - test_split)):int( num_data*( 1 - test_split))]
x_test = data[ int( num_data*( 1 - test_split)):]

y_train = target[ 0:int( num_data*( 1 - val_split - test_split))]
y_val = target[ int( num_data*( 1 - val_split - test_split)):int( num_data*( 1 - test_split))]
y_test = target[ int( num_data*( 1 - test_split)):]

# %%
# x_scaler = preprocessing.StandardScaler().fit( x_train)
# x_train_sc = x_scaler.transform( x_train)
# x_val_sc = x_scaler.transform( x_val)
# x_test_sc = x_scaler.transform( x_test)

# y_scaler = preprocessing.MinMaxScaler().fit( y_train)
# y_train_sc = y_scaler.transform( y_train)
# y_val_sc = y_scaler.transform( y_val)
# y_test_sc = y_scaler.transform( y_test)

# %% [markdown]
# The for loop fits a standardization scaler on every variable in the training set than applies it on the appropriate column in validation and test sets.
#
# Returns a very large warning message about variable saving but unfortunately the bult-in inplace parameter doesn't work.
# I hide it for better readability.
#
# Pandas DataFrame objects are converted to Numpy array for DL models.

# %%
warnings.filterwarnings('ignore')

for col in x_train.columns:
    scaler = preprocessing.StandardScaler().fit(x_train[[col]])
    x_train[[col]]=scaler.transform(x_train[[col]])
    x_val[[col]]=scaler.transform(x_val[[col]])
    x_test[[col]]=scaler.transform(x_test[[col]])
    
x_train_sc_FC = x_train.values
x_val_sc_FC = x_val.values
x_test_sc_FC = x_test.values
    
y_scaler = preprocessing.MinMaxScaler().fit(y_train.values.reshape(-1,1))
y_train_sc_FC = y_scaler.transform( y_train.values.reshape(-1,1))
y_val_sc_FC = y_scaler.transform( y_val.values.reshape(-1,1))
y_test_sc_FC = y_scaler.transform( y_test.values.reshape(-1,1))

warnings.filterwarnings('default')

# %% [markdown]
# I wasn't satisfied with the Fully Connected Network's accuracy and I was curious how accurate a Convolutional Neural Network is therefore I made both models for comparison.
#
# I split the dataset to samples for CNN. One sample contains inputs from more than one time step and only one output value. (we will have to discard some values from the output time series).
#
# The size (time period) of a sample can be specified with the interval_len variable.

# %%
interval_len = 3

# %%
def split_sample( x_var, y_var):
    x, y = list(), list()
    for i in range( len( x_var)):
        end_ix = i + interval_len
        if end_ix > len( x_var):
            break
        seq_x, seq_y = x_var[ i:end_ix, :], y_var[ end_ix-1, :]
        x.append( seq_x)
        y.append( seq_y)
    return np.array( x), np.array( y)

# %%
x_train_sc_CNN, y_train_sc_CNN = split_sample( x_train_sc_FC, y_train_sc_FC)
x_val_sc_CNN, y_val_sc_CNN = split_sample( x_val_sc_FC, y_val_sc_FC)
x_test_sc_CNN, y_test_sc_CNN = split_sample( x_test_sc_FC, y_test_sc_FC)

# %% [markdown]
# ### Model building
#
# Set up early stopping with patience of 30

# %%
from keras.callbacks import EarlyStopping
patience = 30
early_stopping = EarlyStopping( patience = patience, verbose = 1)

from keras.callbacks import ModelCheckpoint
checkpointer_FC = ModelCheckpoint( filepath = "weights_FC.hdf5",
                             save_best_only = True, 
                             verbose = 1 )

checkpointer_CNN = ModelCheckpoint( filepath = "weights_CNN.hdf5",
                             save_best_only = True, 
                             verbose = 1 )

# %% [markdown]
# ### FC model

# %%
model_FC = Sequential()
model_FC.add( Dense( 5, input_shape = (x_train_sc_FC.shape[1],), activation = 'relu', kernel_initializer = 'random_uniform'))
model_FC.add( Dense( 4, input_shape = (x_train_sc_FC.shape[1],), activation = 'relu'))
model_FC.add( Dense( 4, input_shape = (x_train_sc_FC.shape[1],), activation = 'relu'))
model_FC.add( Dense( 4, input_shape = (x_train_sc_FC.shape[1],), activation = 'relu'))
model_FC.add( Dense( 1, activation = 'relu'))

model_FC.compile( loss = 'mean_squared_error', optimizer = 'adam')
model_FC.fit( x_train_sc_FC, y_train_sc_FC, 
          epochs = 100, 
          batch_size = 50, 
          validation_data = ( x_val_sc_FC, y_val_sc_FC),
          shuffle = False,
          callbacks = [ checkpointer_FC,early_stopping])
# Out:
# WARNING:tensorflow:From c:\python\python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2896 samples, validate on 828 samples
# Epoch 1/100
# 2896/2896 [==============================] - 0s 89us/step - loss: 0.2426 - val_loss: 0.1359
#
# Epoch 00001: val_loss improved from inf to 0.13587, saving model to weights_FC.hdf5
# Epoch 2/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0448 - val_loss: 0.0135
#
# Epoch 00002: val_loss improved from 0.13587 to 0.01347, saving model to weights_FC.hdf5
# Epoch 3/100
# 2896/2896 [==============================] - 0s 28us/step - loss: 0.0122 - val_loss: 0.0088
#
# Epoch 00003: val_loss improved from 0.01347 to 0.00884, saving model to weights_FC.hdf5
# Epoch 4/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0081 - val_loss: 0.0059
#
# Epoch 00004: val_loss improved from 0.00884 to 0.00590, saving model to weights_FC.hdf5
# Epoch 5/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0053 - val_loss: 0.0042
#
# Epoch 00005: val_loss improved from 0.00590 to 0.00417, saving model to weights_FC.hdf5
# Epoch 6/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0038 - val_loss: 0.0032
#
# Epoch 00006: val_loss improved from 0.00417 to 0.00325, saving model to weights_FC.hdf5
# Epoch 7/100
# 2896/2896 [==============================] - 0s 28us/step - loss: 0.0030 - val_loss: 0.0027
#
# Epoch 00007: val_loss improved from 0.00325 to 0.00275, saving model to weights_FC.hdf5
# Epoch 8/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00008: val_loss improved from 0.00275 to 0.00249, saving model to weights_FC.hdf5
# Epoch 9/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00009: val_loss improved from 0.00249 to 0.00241, saving model to weights_FC.hdf5
# Epoch 10/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00010: val_loss improved from 0.00241 to 0.00234, saving model to weights_FC.hdf5
# Epoch 11/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00011: val_loss improved from 0.00234 to 0.00230, saving model to weights_FC.hdf5
# Epoch 12/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00012: val_loss improved from 0.00230 to 0.00228, saving model to weights_FC.hdf5
# Epoch 13/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00013: val_loss improved from 0.00228 to 0.00226, saving model to weights_FC.hdf5
# Epoch 14/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00014: val_loss improved from 0.00226 to 0.00224, saving model to weights_FC.hdf5
# Epoch 15/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00015: val_loss improved from 0.00224 to 0.00222, saving model to weights_FC.hdf5
# Epoch 16/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00016: val_loss improved from 0.00222 to 0.00221, saving model to weights_FC.hdf5
# Epoch 17/100
# 2896/2896 [==============================] - 0s 28us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00017: val_loss improved from 0.00221 to 0.00220, saving model to weights_FC.hdf5
# Epoch 18/100
# 2896/2896 [==============================] - 0s 29us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00018: val_loss improved from 0.00220 to 0.00219, saving model to weights_FC.hdf5
# Epoch 19/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00019: val_loss improved from 0.00219 to 0.00218, saving model to weights_FC.hdf5
# Epoch 20/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00020: val_loss improved from 0.00218 to 0.00217, saving model to weights_FC.hdf5
# Epoch 21/100
# 2896/2896 [==============================] - 0s 29us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00021: val_loss improved from 0.00217 to 0.00217, saving model to weights_FC.hdf5
# Epoch 22/100
# 2896/2896 [==============================] - 0s 26us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00022: val_loss improved from 0.00217 to 0.00216, saving model to weights_FC.hdf5
# Epoch 23/100
# 2896/2896 [==============================] - 0s 23us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00023: val_loss improved from 0.00216 to 0.00215, saving model to weights_FC.hdf5
# Epoch 24/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00024: val_loss improved from 0.00215 to 0.00215, saving model to weights_FC.hdf5
# Epoch 25/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00025: val_loss did not improve from 0.00215
# Epoch 26/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00026: val_loss did not improve from 0.00215
# Epoch 27/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00027: val_loss improved from 0.00215 to 0.00214, saving model to weights_FC.hdf5
# Epoch 28/100
# 2896/2896 [==============================] - 0s 27us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00028: val_loss improved from 0.00214 to 0.00214, saving model to weights_FC.hdf5
# Epoch 29/100
# 2896/2896 [==============================] - 0s 24us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00029: val_loss improved from 0.00214 to 0.00214, saving model to weights_FC.hdf5
# Epoch 30/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00030: val_loss did not improve from 0.00214
# Epoch 31/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00031: val_loss did not improve from 0.00214
# Epoch 32/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00032: val_loss did not improve from 0.00214
# Epoch 33/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00033: val_loss did not improve from 0.00214
# Epoch 34/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00034: val_loss improved from 0.00214 to 0.00214, saving model to weights_FC.hdf5
# Epoch 35/100
# 2896/2896 [==============================] - 0s 24us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00035: val_loss did not improve from 0.00214
# Epoch 36/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00036: val_loss improved from 0.00214 to 0.00214, saving model to weights_FC.hdf5
# Epoch 37/100
# 2896/2896 [==============================] - 0s 28us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00037: val_loss did not improve from 0.00214
# Epoch 38/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00038: val_loss did not improve from 0.00214
# Epoch 39/100
# 2896/2896 [==============================] - 0s 24us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00039: val_loss did not improve from 0.00214
# Epoch 40/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00040: val_loss improved from 0.00214 to 0.00214, saving model to weights_FC.hdf5
# Epoch 41/100
# 2896/2896 [==============================] - 0s 25us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00041: val_loss did not improve from 0.00214
# Epoch 42/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00042: val_loss did not improve from 0.00214
# Epoch 43/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00043: val_loss did not improve from 0.00214
# Epoch 44/100
# 2896/2896 [==============================] - 0s 20us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00044: val_loss did not improve from 0.00214
# Epoch 45/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00045: val_loss did not improve from 0.00214
# Epoch 46/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00046: val_loss did not improve from 0.00214
# Epoch 47/100
# 2896/2896 [==============================] - 0s 20us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00047: val_loss did not improve from 0.00214
# Epoch 48/100
# 2896/2896 [==============================] - 0s 19us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00048: val_loss did not improve from 0.00214
# Epoch 49/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00049: val_loss did not improve from 0.00214
# Epoch 50/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00050: val_loss did not improve from 0.00214
# Epoch 51/100
# 2896/2896 [==============================] - 0s 19us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00051: val_loss did not improve from 0.00214
# Epoch 52/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00052: val_loss did not improve from 0.00214
# Epoch 53/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00053: val_loss did not improve from 0.00214
# Epoch 54/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00054: val_loss did not improve from 0.00214
# Epoch 55/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00055: val_loss did not improve from 0.00214
# Epoch 56/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00056: val_loss did not improve from 0.00214
# Epoch 57/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00057: val_loss did not improve from 0.00214
# Epoch 58/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00058: val_loss did not improve from 0.00214
# Epoch 59/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00059: val_loss did not improve from 0.00214
# Epoch 60/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00060: val_loss did not improve from 0.00214
# Epoch 61/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00061: val_loss did not improve from 0.00214
# Epoch 62/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00062: val_loss did not improve from 0.00214
# Epoch 63/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00063: val_loss did not improve from 0.00214
# Epoch 64/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00064: val_loss did not improve from 0.00214
# Epoch 65/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00065: val_loss did not improve from 0.00214
# Epoch 66/100
# 2896/2896 [==============================] - 0s 19us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00066: val_loss did not improve from 0.00214
# Epoch 67/100
# 2896/2896 [==============================] - 0s 22us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00067: val_loss did not improve from 0.00214
# Epoch 68/100
# 2896/2896 [==============================] - 0s 21us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00068: val_loss did not improve from 0.00214
# Epoch 69/100
# 2896/2896 [==============================] - 0s 19us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00069: val_loss did not improve from 0.00214
# Epoch 70/100
# 2896/2896 [==============================] - 0s 23us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00070: val_loss did not improve from 0.00214
# Epoch 00070: early stopping

# %% [markdown]
# ### CNN model

# %%
model_CNN = Sequential()
model_CNN.add( Conv1D( filters = 3, kernel_size = 2, kernel_initializer = 'random_uniform',
                       activation = 'relu', input_shape = ( interval_len, x_train_sc_CNN.shape[2])))
model_CNN.add( Conv1D( filters = 3, kernel_size = 2, kernel_initializer = 'random_uniform',
                       activation = 'relu', input_shape = ( interval_len, x_train_sc_CNN.shape[2])))
model_CNN.add( Flatten())
model_FC.add( Dense( 7, input_shape = ( x_train_sc_FC.shape[1],), activation = 'relu'))
model_FC.add( Dense( 4, input_shape = ( x_train_sc_FC.shape[1],), activation = 'relu'))

model_CNN.add( Dense( 1, activation = 'relu'))
model_CNN.compile( optimizer = 'adam', loss = 'mse')

model_CNN.fit( x_train_sc_CNN, y_train_sc_CNN, 
          epochs = 100,
          batch_size = 50,
          validation_data = ( x_val_sc_CNN, y_val_sc_CNN),
          shuffle = False,
          callbacks = [ checkpointer_CNN, early_stopping])
# Out:
# Train on 2894 samples, validate on 826 samples
# Epoch 1/100
# 2894/2894 [==============================] - 0s 104us/step - loss: 0.2818 - val_loss: 0.2123
#
# Epoch 00001: val_loss improved from inf to 0.21227, saving model to weights_CNN.hdf5
# Epoch 2/100
# 2894/2894 [==============================] - 0s 34us/step - loss: 0.1004 - val_loss: 0.0351
#
# Epoch 00002: val_loss improved from 0.21227 to 0.03507, saving model to weights_CNN.hdf5
# Epoch 3/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0318 - val_loss: 0.0217
#
# Epoch 00003: val_loss improved from 0.03507 to 0.02168, saving model to weights_CNN.hdf5
# Epoch 4/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0225 - val_loss: 0.0153
#
# Epoch 00004: val_loss improved from 0.02168 to 0.01526, saving model to weights_CNN.hdf5
# Epoch 5/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0163 - val_loss: 0.0109
#
# Epoch 00005: val_loss improved from 0.01526 to 0.01090, saving model to weights_CNN.hdf5
# Epoch 6/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0116 - val_loss: 0.0084
#
# Epoch 00006: val_loss improved from 0.01090 to 0.00836, saving model to weights_CNN.hdf5
# Epoch 7/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0089 - val_loss: 0.0068
#
# Epoch 00007: val_loss improved from 0.00836 to 0.00676, saving model to weights_CNN.hdf5
# Epoch 8/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00008: val_loss improved from 0.00676 to 0.00585, saving model to weights_CNN.hdf5
# Epoch 9/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0063 - val_loss: 0.0053
#
# Epoch 00009: val_loss improved from 0.00585 to 0.00525, saving model to weights_CNN.hdf5
# Epoch 10/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0056 - val_loss: 0.0048
#
# Epoch 00010: val_loss improved from 0.00525 to 0.00482, saving model to weights_CNN.hdf5
# Epoch 11/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0051 - val_loss: 0.0045
#
# Epoch 00011: val_loss improved from 0.00482 to 0.00454, saving model to weights_CNN.hdf5
# Epoch 12/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0047 - val_loss: 0.0043
#
# Epoch 00012: val_loss improved from 0.00454 to 0.00431, saving model to weights_CNN.hdf5
# Epoch 13/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0043 - val_loss: 0.0041
#
# Epoch 00013: val_loss improved from 0.00431 to 0.00411, saving model to weights_CNN.hdf5
# Epoch 14/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0041 - val_loss: 0.0039
#
# Epoch 00014: val_loss improved from 0.00411 to 0.00393, saving model to weights_CNN.hdf5
# Epoch 15/100
# 2894/2894 [==============================] - 0s 41us/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00015: val_loss improved from 0.00393 to 0.00376, saving model to weights_CNN.hdf5
# Epoch 16/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0037 - val_loss: 0.0036
#
# Epoch 00016: val_loss improved from 0.00376 to 0.00361, saving model to weights_CNN.hdf5
# Epoch 17/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00017: val_loss improved from 0.00361 to 0.00350, saving model to weights_CNN.hdf5
# Epoch 18/100
# 2894/2894 [==============================] - 0s 42us/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00018: val_loss improved from 0.00350 to 0.00337, saving model to weights_CNN.hdf5
# Epoch 19/100
# 2894/2894 [==============================] - 0s 41us/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00019: val_loss improved from 0.00337 to 0.00327, saving model to weights_CNN.hdf5
# Epoch 20/100
# 2894/2894 [==============================] - 0s 36us/step - loss: 0.0031 - val_loss: 0.0032
#
# Epoch 00020: val_loss improved from 0.00327 to 0.00320, saving model to weights_CNN.hdf5
# Epoch 21/100
# 2894/2894 [==============================] - 0s 42us/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00021: val_loss improved from 0.00320 to 0.00314, saving model to weights_CNN.hdf5
# Epoch 22/100
# 2894/2894 [==============================] - 0s 42us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00022: val_loss improved from 0.00314 to 0.00308, saving model to weights_CNN.hdf5
# Epoch 23/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00023: val_loss improved from 0.00308 to 0.00304, saving model to weights_CNN.hdf5
# Epoch 24/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00024: val_loss improved from 0.00304 to 0.00301, saving model to weights_CNN.hdf5
# Epoch 25/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0028 - val_loss: 0.0030
#
# Epoch 00025: val_loss improved from 0.00301 to 0.00297, saving model to weights_CNN.hdf5
# Epoch 26/100
# 2894/2894 [==============================] - 0s 36us/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00026: val_loss improved from 0.00297 to 0.00294, saving model to weights_CNN.hdf5
# Epoch 27/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00027: val_loss improved from 0.00294 to 0.00291, saving model to weights_CNN.hdf5
# Epoch 28/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00028: val_loss improved from 0.00291 to 0.00288, saving model to weights_CNN.hdf5
# Epoch 29/100
# 2894/2894 [==============================] - 0s 38us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00029: val_loss improved from 0.00288 to 0.00285, saving model to weights_CNN.hdf5
# Epoch 30/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00030: val_loss improved from 0.00285 to 0.00282, saving model to weights_CNN.hdf5
# Epoch 31/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00031: val_loss improved from 0.00282 to 0.00278, saving model to weights_CNN.hdf5
# Epoch 32/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00032: val_loss improved from 0.00278 to 0.00276, saving model to weights_CNN.hdf5
# Epoch 33/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00033: val_loss improved from 0.00276 to 0.00274, saving model to weights_CNN.hdf5
# Epoch 34/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00034: val_loss improved from 0.00274 to 0.00272, saving model to weights_CNN.hdf5
# Epoch 35/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00035: val_loss improved from 0.00272 to 0.00271, saving model to weights_CNN.hdf5
# Epoch 36/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00036: val_loss improved from 0.00271 to 0.00269, saving model to weights_CNN.hdf5
# Epoch 37/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00037: val_loss improved from 0.00269 to 0.00267, saving model to weights_CNN.hdf5
# Epoch 38/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00038: val_loss improved from 0.00267 to 0.00266, saving model to weights_CNN.hdf5
# Epoch 39/100
# 2894/2894 [==============================] - 0s 34us/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00039: val_loss improved from 0.00266 to 0.00263, saving model to weights_CNN.hdf5
# Epoch 40/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00040: val_loss improved from 0.00263 to 0.00260, saving model to weights_CNN.hdf5
# Epoch 41/100
# 2894/2894 [==============================] - 0s 41us/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00041: val_loss improved from 0.00260 to 0.00257, saving model to weights_CNN.hdf5
# Epoch 42/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00042: val_loss improved from 0.00257 to 0.00251, saving model to weights_CNN.hdf5
# Epoch 43/100
# 2894/2894 [==============================] - 0s 42us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00043: val_loss did not improve from 0.00251
# Epoch 44/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00044: val_loss did not improve from 0.00251
# Epoch 45/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00045: val_loss did not improve from 0.00251
# Epoch 46/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00046: val_loss did not improve from 0.00251
# Epoch 47/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00047: val_loss did not improve from 0.00251
# Epoch 48/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00048: val_loss did not improve from 0.00251
# Epoch 49/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00049: val_loss improved from 0.00251 to 0.00250, saving model to weights_CNN.hdf5
# Epoch 50/100
# 2894/2894 [==============================] - 0s 38us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00050: val_loss improved from 0.00250 to 0.00249, saving model to weights_CNN.hdf5
# Epoch 51/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00051: val_loss did not improve from 0.00249
# Epoch 52/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00052: val_loss improved from 0.00249 to 0.00246, saving model to weights_CNN.hdf5
# Epoch 53/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00053: val_loss did not improve from 0.00246
# Epoch 54/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00054: val_loss improved from 0.00246 to 0.00245, saving model to weights_CNN.hdf5
# Epoch 55/100
# 2894/2894 [==============================] - 0s 41us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00055: val_loss did not improve from 0.00245
# Epoch 56/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00056: val_loss improved from 0.00245 to 0.00242, saving model to weights_CNN.hdf5
# Epoch 57/100
# 2894/2894 [==============================] - 0s 43us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00057: val_loss did not improve from 0.00242
# Epoch 58/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00058: val_loss did not improve from 0.00242
# Epoch 59/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00059: val_loss improved from 0.00242 to 0.00237, saving model to weights_CNN.hdf5
# Epoch 60/100
# 2894/2894 [==============================] - 0s 38us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00060: val_loss did not improve from 0.00237
# Epoch 61/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00061: val_loss improved from 0.00237 to 0.00237, saving model to weights_CNN.hdf5
# Epoch 62/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00062: val_loss improved from 0.00237 to 0.00234, saving model to weights_CNN.hdf5
# Epoch 63/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00063: val_loss improved from 0.00234 to 0.00230, saving model to weights_CNN.hdf5
# Epoch 64/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00064: val_loss improved from 0.00230 to 0.00227, saving model to weights_CNN.hdf5
# Epoch 65/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00065: val_loss did not improve from 0.00227
# Epoch 66/100
# 2894/2894 [==============================] - 0s 34us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00066: val_loss did not improve from 0.00227
# Epoch 67/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00067: val_loss improved from 0.00227 to 0.00227, saving model to weights_CNN.hdf5
# Epoch 68/100
# 2894/2894 [==============================] - 0s 42us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00068: val_loss improved from 0.00227 to 0.00226, saving model to weights_CNN.hdf5
# Epoch 69/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00069: val_loss did not improve from 0.00226
# Epoch 70/100
# 2894/2894 [==============================] - 0s 43us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00070: val_loss improved from 0.00226 to 0.00222, saving model to weights_CNN.hdf5
# Epoch 71/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00071: val_loss improved from 0.00222 to 0.00222, saving model to weights_CNN.hdf5
# Epoch 72/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00072: val_loss did not improve from 0.00222
# Epoch 73/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00073: val_loss did not improve from 0.00222
# Epoch 74/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00074: val_loss improved from 0.00222 to 0.00220, saving model to weights_CNN.hdf5
# Epoch 75/100
# 2894/2894 [==============================] - 0s 46us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00075: val_loss improved from 0.00220 to 0.00220, saving model to weights_CNN.hdf5
# Epoch 76/100
# 2894/2894 [==============================] - 0s 46us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00076: val_loss did not improve from 0.00220
# Epoch 77/100
# 2894/2894 [==============================] - 0s 44us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00077: val_loss did not improve from 0.00220
# Epoch 78/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00078: val_loss did not improve from 0.00220
# Epoch 79/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00079: val_loss did not improve from 0.00220
# Epoch 80/100
# 2894/2894 [==============================] - 0s 36us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00080: val_loss did not improve from 0.00220
# Epoch 81/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00081: val_loss improved from 0.00220 to 0.00219, saving model to weights_CNN.hdf5
# Epoch 82/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00082: val_loss improved from 0.00219 to 0.00216, saving model to weights_CNN.hdf5
# Epoch 83/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00083: val_loss did not improve from 0.00216
# Epoch 84/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00084: val_loss did not improve from 0.00216
# Epoch 85/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00085: val_loss did not improve from 0.00216
# Epoch 86/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00086: val_loss did not improve from 0.00216
# Epoch 87/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00087: val_loss did not improve from 0.00216
# Epoch 88/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00088: val_loss did not improve from 0.00216
# Epoch 89/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00089: val_loss did not improve from 0.00216
# Epoch 90/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00090: val_loss did not improve from 0.00216
# Epoch 91/100
# 2894/2894 [==============================] - 0s 35us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00091: val_loss did not improve from 0.00216
# Epoch 92/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00092: val_loss did not improve from 0.00216
# Epoch 93/100
# 2894/2894 [==============================] - 0s 33us/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00093: val_loss improved from 0.00216 to 0.00214, saving model to weights_CNN.hdf5
# Epoch 94/100
# 2894/2894 [==============================] - 0s 37us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00094: val_loss did not improve from 0.00214
# Epoch 95/100
# 2894/2894 [==============================] - 0s 40us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00095: val_loss did not improve from 0.00214
# Epoch 96/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00096: val_loss did not improve from 0.00214
# Epoch 97/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00097: val_loss did not improve from 0.00214
# Epoch 98/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00098: val_loss did not improve from 0.00214
# Epoch 99/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00099: val_loss improved from 0.00214 to 0.00214, saving model to weights_CNN.hdf5
# Epoch 100/100
# 2894/2894 [==============================] - 0s 39us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00100: val_loss did not improve from 0.00214

# %% [markdown]
# ### Comparison
#
# Load the best model then calculate model predictions for MSE and visualization.
#
# It has to be noted that the last - forecast_period length - values in the target column are NaN's because of the time shifting therefore I cut them out where it's needed.

# %%
from keras.models import load_model

model_FC = load_model( 'weights_FC.hdf5')
model_CNN = load_model( 'weights_CNN.hdf5')

# %%
pred_FC = model_FC.predict( x_test_sc_FC)
pred_FC = y_scaler.inverse_transform( pred_FC)
targ_FC = y_scaler.inverse_transform( y_test_sc_FC)

pred_CNN = model_CNN.predict( x_test_sc_CNN)
pred_CNN = y_scaler.inverse_transform( pred_CNN)
targ_CNN = y_scaler.inverse_transform( y_test_sc_CNN)

# %%
from sklearn.metrics import mean_squared_error

test_mse_FC = mean_squared_error( targ_FC[ :-forecast_period], pred_FC[ :-forecast_period])
test_mse_CNN = mean_squared_error( targ_CNN[ :-forecast_period], pred_CNN[ :-forecast_period])

print('TEST MSE FC: %f' % ( test_mse_FC),'\nTEST MSE CNN: %f' % ( test_mse_CNN))
# Out:
# TEST MSE FC: 6.863209
# TEST MSE CNN: 6.199301

# %%
plt.figure( figsize= ( 15, 5))
plt.plot( targ_FC[ :-forecast_period])
plt.plot( pred_FC[ :-forecast_period])
plt.title( 'Fully Connected Network')
plt.legend( labels = [ 'Target', 'Predicted'])

# %%
plt.figure( figsize= ( 15, 5))
plt.plot( targ_CNN[:-forecast_period])
plt.plot( pred_CNN[:-forecast_period])
plt.title('Convolutional Neural Network')
plt.legend( labels=['Target', 'Predicted'])

# %% [markdown]
# ### Conclusion
#
# The CNN network is usually a bit better than the FC but the hypermarameters influence the accuracy very strongly.
#
# The prediction time interval is set in the beginning therefore the script must be re-run when we select 1 day, 7 day or 28 day. It always prints out the current estimated day's temperature that's why I write the needed estimations in a markdown cell.

# %%
print( 'FC prediction: %f °C' % ( pred_FC[-1]), '\nCNN prediction: %f °C' % ( pred_CNN[-1]))
# Out:
# FC prediction: 8.942622 °C
# CNN prediction: 7.969611 °C

# %% [markdown]
#   Estimated day   | FC            | CNN
#   --------------- | ------------- | --------
#   October 30      | 8.942622 °C   | 7.969611 °C
#   November 5      | 10.062304 °C  | 9.946683 °C
#   November 26     | 10.239018 °C  | 2.503098 °C
